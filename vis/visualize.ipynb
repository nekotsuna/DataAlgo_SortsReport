# %%
# !uv add matplotlib
# Out:
# Resolved 12 packages in 1ms
# Audited 11 packages in 0.01ms

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# JSON ファイルを読み込む（ファイル名は適宜変更してください）
with open('../benchmark/result.json', 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# {'random_1_0': {'type': 'random',
#   'length': 1,
#   'seed': 8044,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.3000000000002185e-06,
#    'heapsort_ascend': 6.699999999998374e-06,
#    'insertsort_ascend': 1.7999999999997185e-06,
#    'mergesort_ascend': 9.999999999975306e-07,
#    'quicksort_ascend': 1.7999999999997185e-06,
#    'selectsort_ascend': 3.199999999998343e-06}},
#  'random_1_1': {'type': 'random',
#   'length': 1,
#   'seed': 9149,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 1.7999999999997185e-06,
#    'heapsort_ascend': 1.5199999999999936e-05,
#    'insertsort_ascend': 1.7999999999997185e-06,
#    'mergesort_ascend': 1.7000000000003124e-06,
#    'quicksort_ascend': 1.1999999999998123e-06,
#    'selectsort_ascend': 2.8000000000007186e-06}},
#  'random_1_2': {'type': 'random',
#   'length': 1,
#   'seed': 9182,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 2.4999999999990308e-06,
#    'heapsort_ascend': 4.199999999999343e-06,
#    'insertsort_ascend': 1.2999999999992184e-06,
#    'mergesort_ascend': 8.999999999981245e-07,
#    'quicksort_ascend': 1.000000000001e-06,
#    'selectsort_ascend': 1.4999999999980307e-06}},
#  'random_10_0': {'type': 'random',
#   'length': 10,
#   'seed': 8211,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.2400000000002687e-05,
#    'heapsort_ascend': 3.3600000000001684e-05,
#    'insertsort_ascend': 1.6000000000002124e-05,
#    'mergesort_ascend': 2.839999999999787e-05,
#    'quicksort_ascend': 1.5500000000001624e-05,
#    'selectsort_ascend': 1.0799999999998311e-05}},
#  'random_10_1': {'type': 'random',
#   'length': 10,
#   'seed': 8159,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 1.0799999999998311e-05,
#    'heapsort_ascend': 3.18999999999979e-05,
#    'insertsort_ascend': 1.0099999999998999e-05,
#    'mergesort_ascend': 2.9799999999999965e-05,
#    'quicksort_ascend': 1.860000000000056e-05,
#    'selectsort_ascend': 8.999999999998592e-06}},
#  'random_10_2': {'type': 'random',
#   'length': 10,
#   'seed': 1005,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 1.2200000000000405e-05,
#    'heapsort_ascend': 3.3299999999999996e-05,
#    'insertsort_ascend': 8.500000000001562e-06,
#    'mergesort_ascend': 2.8000000000000247e-05,
#    'quicksort_ascend': 1.0500000000000093e-05,
#    'selectsort_ascend': 8.199999999999874e-06}},
#  'random_100_0': {'type': 'random',
#   'length': 100,
#   'seed': 2008,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.0012469999999999981,
#    'heapsort_ascend': 0.0008691000000000011,
#    'insertsort_ascend': 0.00025099999999999775,
#    'mergesort_ascend': 0.0004275000000000008,
#    'quicksort_ascend': 0.00019759999999999917,
#    'selectsort_ascend': 0.0005056000000000019}},
#  'random_100_1': {'type': 'random',
#   'length': 100,
#   'seed': 8001,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.000764299999999999,
#    'heapsort_ascend': 0.0007766999999999982,
#    'insertsort_ascend': 0.00018270000000000092,
#    'mergesort_ascend': 0.0002707999999999981,
#    'quicksort_ascend': 0.00017239999999999964,
#    'selectsort_ascend': 0.0003516000000000005}},
#  'random_100_2': {'type': 'random',
#   'length': 100,
#   'seed': 4468,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.00043430000000000205,
#    'heapsort_ascend': 0.00028000000000000247,
#    'insertsort_ascend': 0.00015099999999999836,
#    'mergesort_ascend': 0.0002711999999999992,
#    'quicksort_ascend': 0.0001436999999999966,
#    'selectsort_ascend': 0.00022869999999999835}},
#  'random_1000_0': {'type': 'random',
#   'length': 1000,
#   'seed': 1766,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.06616959999973915,
#    'heapsort_ascend': 0.006255000000237487,
#    'insertsort_ascend': 0.0160185999998248,
#    'mergesort_ascend': 0.0032983999999487423,
#    'quicksort_ascend': 0.0016909999999370484,
#    'selectsort_ascend': 0.01940710000008039}},
#  'random_1000_1': {'type': 'random',
#   'length': 1000,
#   'seed': 3642,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.05984520000038174,
#    'heapsort_ascend': 0.004137599999921804,
#    'insertsort_ascend': 0.021934800000053656,
#    'mergesort_ascend': 0.0054556999998567335,
#    'quicksort_ascend': 0.0024966000000858912,
#    'selectsort_ascend': 0.023052799999732088}},
#  'random_1000_2': {'type': 'random',
#   'length': 1000,
#   'seed': 706,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.07554540000000998,
#    'heapsort_ascend': 0.00643209999998362,
#    'insertsort_ascend': 0.015605600000071718,
#    'mergesort_ascend': 0.0026385999999547494,
#    'quicksort_ascend': 0.0013018999998166692,
#    'selectsort_ascend': 0.017826700000114215}},
#  'random_10000_0': {'type': 'random',
#   'length': 10000,
#   'seed': 9200,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 4.6621852,
#    'heapsort_ascend': 0.06013599999999997,
#    'insertsort_ascend': 1.4164987,
#    'mergesort_ascend': 0.041037400000000446,
#    'quicksort_ascend': 0.019072200000000095,
#    'selectsort_ascend': 1.6159227999999999}},
#  'random_10000_1': {'type': 'random',
#   'length': 10000,
#   'seed': 307,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 5.096818900000001,
#    'heapsort_ascend': 0.04776430000000076,
#    'insertsort_ascend': 1.4651422000000007,
#    'mergesort_ascend': 0.031245800000000656,
#    'quicksort_ascend': 0.01921610000000129,
#    'selectsort_ascend': 1.6811211000000004}},
#  'random_10000_2': {'type': 'random',
#   'length': 10000,
#   'seed': 7942,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 5.3186246,
#    'heapsort_ascend': 0.06650259999999975,
#    'insertsort_ascend': 1.9820768999999991,
#    'mergesort_ascend': 0.03486249999999913,
#    'quicksort_ascend': 0.01668430000000143,
#    'selectsort_ascend': 1.6984808999999998}},
#  'random_100000_0': {'type': 'random',
#   'length': 100000,
#   'seed': 1625,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 558.4179514,
#    'heapsort_ascend': 0.7415236000000505,
#    'insertsort_ascend': 191.14149180000004,
#    'mergesort_ascend': 0.5709229999999934,
#    'quicksort_ascend': 0.2715327000000798,
#    'selectsort_ascend': 176.51122959999998}},
#  'random_100000_1': {'type': 'random',
#   'length': 100000,
#   'seed': 635,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 607.4739491,
#    'heapsort_ascend': 0.7391153000000941,
#    'insertsort_ascend': 181.80719900000008,
#    'mergesort_ascend': 0.4130299000000832,
#    'quicksort_ascend': 0.21644599999990533,
#    'selectsort_ascend': 166.8976760999999}},
#  'random_100000_2': {'type': 'random',
#   'length': 100000,
#   'seed': 6647,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 521.9693106999998,
#    'heapsort_ascend': 0.6224857000001975,
#    'insertsort_ascend': 155.86315239999976,
#    'mergesort_ascend': 0.38266590000012,
#    'quicksort_ascend': 0.20175749999998516,
#    'selectsort_ascend': 169.34699799999999}},
#  'random_2000_0': {'type': 'random',
#   'length': 2000,
#   'seed': 1326,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.20933970000032787,
#    'heapsort_ascend': 0.007721599999968021,
#    'insertsort_ascend': 0.06225589999985459,
#    'mergesort_ascend': 0.0050138999999944645,
#    'quicksort_ascend': 0.0025793999998313666,
#    'selectsort_ascend': 0.0642811999996411}},
#  'random_2000_1': {'type': 'random',
#   'length': 2000,
#   'seed': 4946,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.20088609999993423,
#    'heapsort_ascend': 0.00793489999978192,
#    'insertsort_ascend': 0.06384329999991678,
#    'mergesort_ascend': 0.005283700000290992,
#    'quicksort_ascend': 0.002587299999959214,
#    'selectsort_ascend': 0.130130100000315}},
#  'random_2000_2': {'type': 'random',
#   'length': 2000,
#   'seed': 3001,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.20797540000012305,
#    'heapsort_ascend': 0.007889199999681296,
#    'insertsort_ascend': 0.05740659999992204,
#    'mergesort_ascend': 0.005046699999638804,
#    'quicksort_ascend': 0.0024764999998296844,
#    'selectsort_ascend': 0.06517600000006496}},
#  'random_3000_0': {'type': 'random',
#   'length': 3000,
#   'seed': 5282,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.43233569999983956,
#    'heapsort_ascend': 0.011689599999954225,
#    'insertsort_ascend': 0.12078269999983604,
#    'mergesort_ascend': 0.0076902000000700355,
#    'quicksort_ascend': 0.0037850000003345485,
#    'selectsort_ascend': 0.13831889999983105}},
#  'random_3000_1': {'type': 'random',
#   'length': 3000,
#   'seed': 7552,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.41443400000025576,
#    'heapsort_ascend': 0.012079199999789125,
#    'insertsort_ascend': 0.13022069999988162,
#    'mergesort_ascend': 0.007900699999936478,
#    'quicksort_ascend': 0.003946399999676942,
#    'selectsort_ascend': 0.1452606999996533}},
#  'random_3000_2': {'type': 'random',
#   'length': 3000,
#   'seed': 5282,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.43539389999978084,
#    'heapsort_ascend': 0.011824500000329863,
#    'insertsort_ascend': 0.14932939999971495,
#    'mergesort_ascend': 0.008599199999935081,
#    'quicksort_ascend': 0.004207200000109879,
#    'selectsort_ascend': 0.1493428999997377}},
#  'random_4000_0': {'type': 'random',
#   'length': 4000,
#   'seed': 7552,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.7934540999999626,
#    'heapsort_ascend': 0.01719279999997525,
#    'insertsort_ascend': 0.24930589999985386,
#    'mergesort_ascend': 0.022382199999810837,
#    'quicksort_ascend': 0.01632259999996677,
#    'selectsort_ascend': 0.34113029999980427}},
#  'random_4000_1': {'type': 'random',
#   'length': 4000,
#   'seed': 9836,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.9220070999999734,
#    'heapsort_ascend': 0.023649099999602186,
#    'insertsort_ascend': 0.29641750000018874,
#    'mergesort_ascend': 0.022335199999815813,
#    'quicksort_ascend': 0.007869300000038493,
#    'selectsort_ascend': 0.32088849999991}},
#  'random_4000_2': {'type': 'random',
#   'length': 4000,
#   'seed': 7215,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 1.1395458999995753,
#    'heapsort_ascend': 0.01921360000005734,
#    'insertsort_ascend': 0.2593968999999561,
#    'mergesort_ascend': 0.01169770000024073,
#    'quicksort_ascend': 0.00631729999986419,
#    'selectsort_ascend': 0.25819559999990815}},
#  'random_5000_0': {'type': 'random',
#   'length': 5000,
#   'seed': 3719,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.2118093999997654,
#    'heapsort_ascend': 0.02158030000009603,
#    'insertsort_ascend': 0.36044070000025386,
#    'mergesort_ascend': 0.013015400000313093,
#    'quicksort_ascend': 0.006787499999973079,
#    'selectsort_ascend': 0.4233509000000595}},
#  'random_5000_1': {'type': 'random',
#   'length': 5000,
#   'seed': 1233,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 1.4168690999999853,
#    'heapsort_ascend': 0.02136030000019673,
#    'insertsort_ascend': 0.3408118000002105,
#    'mergesort_ascend': 0.013167800000246643,
#    'quicksort_ascend': 0.006513700000141398,
#    'selectsort_ascend': 0.3790162999998756}},
#  'random_5000_2': {'type': 'random',
#   'length': 5000,
#   'seed': 969,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 1.20237810000026,
#    'heapsort_ascend': 0.02267470000015237,
#    'insertsort_ascend': 0.37946270000020377,
#    'mergesort_ascend': 0.013639100000091275,
#    'quicksort_ascend': 0.006717700000081095,
#    'selectsort_ascend': 0.43335639999986597}},
#  'random_6000_0': {'type': 'random',
#   'length': 6000,
#   'seed': 218,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.6994629000000714,
#    'heapsort_ascend': 0.02574720000029629,
#    'insertsort_ascend': 0.5584745999999541,
#    'mergesort_ascend': 0.018413699999655364,
#    'quicksort_ascend': 0.009135700000115321,
#    'selectsort_ascend': 0.5840502999999444}},
#  'random_6000_1': {'type': 'random',
#   'length': 6000,
#   'seed': 9730,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 1.7199459999997089,
#    'heapsort_ascend': 0.023787699999957113,
#    'insertsort_ascend': 0.469139400000131,
#    'mergesort_ascend': 0.015296699999908014,
#    'quicksort_ascend': 0.007796500000040396,
#    'selectsort_ascend': 0.5308604000001651}},
#  'random_6000_2': {'type': 'random',
#   'length': 6000,
#   'seed': 8359,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 2.0369136999997863,
#    'heapsort_ascend': 0.031014700000014273,
#    'insertsort_ascend': 0.6157831999998962,
#    'mergesort_ascend': 0.01769190000004528,
#    'quicksort_ascend': 0.008568799999920884,
#    'selectsort_ascend': 0.595774899999924}},
#  'random_7000_0': {'type': 'random',
#   'length': 7000,
#   'seed': 3304,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.397841999999855,
#    'heapsort_ascend': 0.03378229999998439,
#    'insertsort_ascend': 0.7363165000001572,
#    'mergesort_ascend': 0.019702999999935855,
#    'quicksort_ascend': 0.010675200000150653,
#    'selectsort_ascend': 0.7923639999999068}},
#  'random_7000_1': {'type': 'random',
#   'length': 7000,
#   'seed': 6998,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 2.5045666000000892,
#    'heapsort_ascend': 0.03184980000014548,
#    'insertsort_ascend': 0.7975987999998324,
#    'mergesort_ascend': 0.020189299999856303,
#    'quicksort_ascend': 0.01160070000014457,
#    'selectsort_ascend': 0.8930817999998908}},
#  'random_7000_2': {'type': 'random',
#   'length': 7000,
#   'seed': 3709,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 2.614981899999748,
#    'heapsort_ascend': 0.04625639999994746,
#    'insertsort_ascend': 0.8765034000002743,
#    'mergesort_ascend': 0.02068280000003142,
#    'quicksort_ascend': 0.01021149999996851,
#    'selectsort_ascend': 0.8500900999997612}},
#  'random_8000_0': {'type': 'random',
#   'length': 8000,
#   'seed': 818,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 3.282195100000081,
#    'heapsort_ascend': 0.0372256999999081,
#    'insertsort_ascend': 0.9764655000003586,
#    'mergesort_ascend': 0.024290100000143866,
#    'quicksort_ascend': 0.012814799999887327,
#    'selectsort_ascend': 1.1032408999999461}},
#  'random_8000_1': {'type': 'random',
#   'length': 8000,
#   'seed': 9814,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 3.4499728000000687,
#    'heapsort_ascend': 0.06091459999970539,
#    'insertsort_ascend': 1.2460900000000947,
#    'mergesort_ascend': 0.027866899999935413,
#    'quicksort_ascend': 0.020919099999900936,
#    'selectsort_ascend': 1.1568621999999777}},
#  'random_8000_2': {'type': 'random',
#   'length': 8000,
#   'seed': 8340,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 3.193297899999834,
#    'heapsort_ascend': 0.040410699999938515,
#    'insertsort_ascend': 1.0765566000000035,
#    'mergesort_ascend': 0.02303040000015244,
#    'quicksort_ascend': 0.01290610000023662,
#    'selectsort_ascend': 1.1254587000003085}},
#  'random_9000_0': {'type': 'random',
#   'length': 9000,
#   'seed': 6405,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 4.309163299999909,
#    'heapsort_ascend': 0.04201180000018212,
#    'insertsort_ascend': 1.1739407999998548,
#    'mergesort_ascend': 0.02672519999987344,
#    'quicksort_ascend': 0.013564900000346825,
#    'selectsort_ascend': 1.2796469999998408}},
#  'random_9000_1': {'type': 'random',
#   'length': 9000,
#   'seed': 4539,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 4.223241500000313,
#    'heapsort_ascend': 0.04597719999992478,
#    'insertsort_ascend': 1.1338018999999804,
#    'mergesort_ascend': 0.024050500000157626,
#    'quicksort_ascend': 0.012564600000132486,
#    'selectsort_ascend': 1.1983758999999736}},
#  'random_9000_2': {'type': 'random',
#   'length': 9000,
#   'seed': 2330,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 3.884932999999819,
#    'heapsort_ascend': 0.041280400000232476,
#    'insertsort_ascend': 1.1525805999999648,
#    'mergesort_ascend': 0.024967299999843817,
#    'quicksort_ascend': 0.012871200000063254,
#    'selectsort_ascend': 1.5165797000004204}},
#  'duplicated_1_0': {'type': 'duplicated',
#   'length': 1,
#   'seed': 338,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 9.649999992689118e-05,
#    'heapsort_ascend': 7.300000106624793e-06,
#    'insertsort_ascend': 1.100000190490391e-06,
#    'mergesort_ascend': 9.000000318337698e-07,
#    'quicksort_ascend': 9.000000318337698e-07,
#    'selectsort_ascend': 1.500000053056283e-06}},
#  'duplicated_1_1': {'type': 'duplicated',
#   'length': 1,
#   'seed': 6753,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 2.3000002329354174e-06,
#    'heapsort_ascend': 4.399999852466863e-06,
#    'insertsort_ascend': 1.3000003491470125e-06,
#    'mergesort_ascend': 9.99999883788405e-07,
#    'quicksort_ascend': 1.2000000424450263e-06,
#    'selectsort_ascend': 2.100000074278796e-06}},
#  'duplicated_1_2': {'type': 'duplicated',
#   'length': 1,
#   'seed': 1189,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 1.5999999050109182e-06,
#    'heapsort_ascend': 2.7999999474559445e-06,
#    'insertsort_ascend': 1.3999997463542968e-06,
#    'mergesort_ascend': 1.2000000424450263e-06,
#    'quicksort_ascend': 6.999998731771484e-07,
#    'selectsort_ascend': 1.600000359758269e-06}},
#  'duplicated_10_0': {'type': 'duplicated',
#   'length': 10,
#   'seed': 8617,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 8.299999990413198e-06,
#    'heapsort_ascend': 1.9699999938893598e-05,
#    'insertsort_ascend': 6.199999916134402e-06,
#    'mergesort_ascend': 1.75999998646148e-05,
#    'quicksort_ascend': 1.06999996205559e-05,
#    'selectsort_ascend': 6.199999916134402e-06}},
#  'duplicated_10_1': {'type': 'duplicated',
#   'length': 10,
#   'seed': 1724,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 7.899999673099956e-06,
#    'heapsort_ascend': 1.8799999907059828e-05,
#    'insertsort_ascend': 6.199999916134402e-06,
#    'mergesort_ascend': 1.7999999727180693e-05,
#    'quicksort_ascend': 8.099999831756577e-06,
#    'selectsort_ascend': 6.300000222836388e-06}},
#  'duplicated_10_2': {'type': 'duplicated',
#   'length': 10,
#   'seed': 5267,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 7.300000106624793e-06,
#    'heapsort_ascend': 1.739999970595818e-05,
#    'insertsort_ascend': 6.199999916134402e-06,
#    'mergesort_ascend': 1.699999984339229e-05,
#    'quicksort_ascend': 9.60000033956021e-06,
#    'selectsort_ascend': 7.900000127847306e-06}},
#  'duplicated_100_0': {'type': 'duplicated',
#   'length': 100,
#   'seed': 156,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.00035840000009557116,
#    'heapsort_ascend': 0.0002165999999306223,
#    'insertsort_ascend': 0.00018650000038178405,
#    'mergesort_ascend': 0.00019410000004427275,
#    'quicksort_ascend': 4.0500000068277586e-05,
#    'selectsort_ascend': 0.00015729999995528487}},
#  'duplicated_100_1': {'type': 'duplicated',
#   'length': 100,
#   'seed': 7441,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.000349999999798456,
#    'heapsort_ascend': 0.0002351999996790255,
#    'insertsort_ascend': 0.00016969999978755368,
#    'mergesort_ascend': 0.00019819999988612835,
#    'quicksort_ascend': 3.6499999623629265e-05,
#    'selectsort_ascend': 0.00015870000015638652}},
#  'duplicated_100_2': {'type': 'duplicated',
#   'length': 100,
#   'seed': 4255,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.00039000000015221303,
#    'heapsort_ascend': 0.00021440000000438886,
#    'insertsort_ascend': 0.00015389999998660642,
#    'mergesort_ascend': 0.00019569999994928367,
#    'quicksort_ascend': 3.5600000046542846e-05,
#    'selectsort_ascend': 0.00015620000021954183}},
#  'duplicated_1000_0': {'type': 'duplicated',
#   'length': 1000,
#   'seed': 8706,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.0416096999997535,
#    'heapsort_ascend': 0.0032315000007656636,
#    'insertsort_ascend': 0.015122100000553473,
#    'mergesort_ascend': 0.0024464999996780534,
#    'quicksort_ascend': 0.0007078999997247593,
#    'selectsort_ascend': 0.015389899999718182}},
#  'duplicated_1000_1': {'type': 'duplicated',
#   'length': 1000,
#   'seed': 4901,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.04470060000039666,
#    'heapsort_ascend': 0.003115100000286475,
#    'insertsort_ascend': 0.014319900000373309,
#    'mergesort_ascend': 0.00243399999999383,
#    'quicksort_ascend': 0.00046720000045752386,
#    'selectsort_ascend': 0.015543100000286358}},
#  'duplicated_1000_2': {'type': 'duplicated',
#   'length': 1000,
#   'seed': 5549,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.05682450000040262,
#    'heapsort_ascend': 0.0033899999998538988,
#    'insertsort_ascend': 0.015807200000381272,
#    'mergesort_ascend': 0.002504399999452289,
#    'quicksort_ascend': 0.00044939999952475773,
#    'selectsort_ascend': 0.017750900000464753}},
#  'duplicated_10000_0': {'type': 'duplicated',
#   'length': 10000,
#   'seed': 895,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 4.650751299999683,
#    'heapsort_ascend': 0.039039799999954994,
#    'insertsort_ascend': 1.6206959000001007,
#    'mergesort_ascend': 0.031327499999861175,
#    'quicksort_ascend': 0.0032304999999723805,
#    'selectsort_ascend': 1.6348423999997976}},
#  'duplicated_10000_1': {'type': 'duplicated',
#   'length': 10000,
#   'seed': 4378,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 4.549860999999964,
#    'heapsort_ascend': 0.045242099999995844,
#    'insertsort_ascend': 1.5012102000000596,
#    'mergesort_ascend': 0.03549930000008317,
#    'quicksort_ascend': 0.002783199999612407,
#    'selectsort_ascend': 1.6172667000000729}},
#  'duplicated_10000_2': {'type': 'duplicated',
#   'length': 10000,
#   'seed': 6865,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 4.73339470000019,
#    'heapsort_ascend': 0.039748299999700976,
#    'insertsort_ascend': 1.6023699000002125,
#    'mergesort_ascend': 0.053829099999802565,
#    'quicksort_ascend': 0.005913799999689218,
#    'selectsort_ascend': 1.9003010000001268}},
#  'duplicated_100000_0': {'type': 'duplicated',
#   'length': 100000,
#   'seed': 9815,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 447.4148537000001,
#    'heapsort_ascend': 0.508440999999948,
#    'insertsort_ascend': 161.61583120000023,
#    'mergesort_ascend': 0.3585670999996182,
#    'quicksort_ascend': 0.02355020000004515,
#    'selectsort_ascend': 162.00121880000006}},
#  'duplicated_100000_1': {'type': 'duplicated',
#   'length': 100000,
#   'seed': 2172,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 459.75918269999966,
#    'heapsort_ascend': 0.501901000000089,
#    'insertsort_ascend': 164.3111911000001,
#    'mergesort_ascend': 0.39321300000028714,
#    'quicksort_ascend': 0.02949850000004517,
#    'selectsort_ascend': 162.62392720000025}},
#  'duplicated_100000_2': {'type': 'duplicated',
#   'length': 100000,
#   'seed': 8138,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 462.2591000000002,
#    'heapsort_ascend': 0.5758170999997674,
#    'insertsort_ascend': 182.4760126000001,
#    'mergesort_ascend': 0.3425330000000031,
#    'quicksort_ascend': 0.028130500000770553,
#    'selectsort_ascend': 155.63425759999973}},
#  'duplicated_2000_0': {'type': 'duplicated',
#   'length': 2000,
#   'seed': 4247,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.18439870000020164,
#    'heapsort_ascend': 0.006885400000101072,
#    'insertsort_ascend': 0.0583838000002288,
#    'mergesort_ascend': 0.005145400000401423,
#    'quicksort_ascend': 0.0006567999998878804,
#    'selectsort_ascend': 0.06082640000022366}},
#  'duplicated_2000_1': {'type': 'duplicated',
#   'length': 2000,
#   'seed': 2687,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.17514219999975467,
#    'heapsort_ascend': 0.006612299999687821,
#    'insertsort_ascend': 0.05780339999910211,
#    'mergesort_ascend': 0.004989900000509806,
#    'quicksort_ascend': 0.0005369999998947605,
#    'selectsort_ascend': 0.061193599999569415}},
#  'duplicated_2000_2': {'type': 'duplicated',
#   'length': 2000,
#   'seed': 3937,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.18224220000047353,
#    'heapsort_ascend': 0.008260500000687898,
#    'insertsort_ascend': 0.0654050000002826,
#    'mergesort_ascend': 0.005743699999584351,
#    'quicksort_ascend': 0.0008306999998239917,
#    'selectsort_ascend': 0.07519890000003215}},
#  'duplicated_3000_0': {'type': 'duplicated',
#   'length': 3000,
#   'seed': 4000,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.4530843000002278,
#    'heapsort_ascend': 0.011290900000858528,
#    'insertsort_ascend': 0.1368360999995275,
#    'mergesort_ascend': 0.008372199999939767,
#    'quicksort_ascend': 0.0008033000003706547,
#    'selectsort_ascend': 0.141407000000072}},
#  'duplicated_3000_1': {'type': 'duplicated',
#   'length': 3000,
#   'seed': 8355,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.41183790000013687,
#    'heapsort_ascend': 0.011326200000439712,
#    'insertsort_ascend': 0.13531720000082714,
#    'mergesort_ascend': 0.008114600000226346,
#    'quicksort_ascend': 0.000828400000500551,
#    'selectsort_ascend': 0.13953130000027159}},
#  'duplicated_3000_2': {'type': 'duplicated',
#   'length': 3000,
#   'seed': 1288,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.39424869999947987,
#    'heapsort_ascend': 0.01081360000080167,
#    'insertsort_ascend': 0.13050919999932376,
#    'mergesort_ascend': 0.007942400000501948,
#    'quicksort_ascend': 0.0009684999995442922,
#    'selectsort_ascend': 0.13675599999987753}},
#  'duplicated_4000_0': {'type': 'duplicated',
#   'length': 4000,
#   'seed': 2081,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.7017581000000064,
#    'heapsort_ascend': 0.014561099999809812,
#    'insertsort_ascend': 0.23378690000026836,
#    'mergesort_ascend': 0.01235259999975824,
#    'quicksort_ascend': 0.0011380999994798913,
#    'selectsort_ascend': 0.36174839999966935}},
#  'duplicated_4000_1': {'type': 'duplicated',
#   'length': 4000,
#   'seed': 5028,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 0.7532065000004877,
#    'heapsort_ascend': 0.014522599999509112,
#    'insertsort_ascend': 0.2276123000001462,
#    'mergesort_ascend': 0.01066739999987476,
#    'quicksort_ascend': 0.0010985999997501494,
#    'selectsort_ascend': 0.24567500000011933}},
#  'duplicated_4000_2': {'type': 'duplicated',
#   'length': 4000,
#   'seed': 9009,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 0.6880989000001136,
#    'heapsort_ascend': 0.01563460000033956,
#    'insertsort_ascend': 0.24732159999985015,
#    'mergesort_ascend': 0.011342700000568584,
#    'quicksort_ascend': 0.0011783999998442596,
#    'selectsort_ascend': 0.25527300000067044}},
#  'duplicated_5000_0': {'type': 'duplicated',
#   'length': 5000,
#   'seed': 5357,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.1605792000000292,
#    'heapsort_ascend': 0.021835900000041875,
#    'insertsort_ascend': 0.4027067999995779,
#    'mergesort_ascend': 0.014633599999797298,
#    'quicksort_ascend': 0.0015453999994861078,
#    'selectsort_ascend': 0.4070188000005146}},
#  'duplicated_5000_1': {'type': 'duplicated',
#   'length': 5000,
#   'seed': 5889,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 1.125204500000109,
#    'heapsort_ascend': 0.01959790000000794,
#    'insertsort_ascend': 0.3719870000004448,
#    'mergesort_ascend': 0.015237699999488541,
#    'quicksort_ascend': 0.0017721999993227655,
#    'selectsort_ascend': 0.44291769999927055}},
#  'duplicated_5000_2': {'type': 'duplicated',
#   'length': 5000,
#   'seed': 7529,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 1.1184155999999348,
#    'heapsort_ascend': 0.018617299999277748,
#    'insertsort_ascend': 0.3965244999999413,
#    'mergesort_ascend': 0.02134380000006786,
#    'quicksort_ascend': 0.001547500000015134,
#    'selectsort_ascend': 0.4093865000004371}},
#  'duplicated_6000_0': {'type': 'duplicated',
#   'length': 6000,
#   'seed': 8965,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.5443398999996134,
#    'heapsort_ascend': 0.023774699999194127,
#    'insertsort_ascend': 0.5379359999997178,
#    'mergesort_ascend': 0.016962700000476616,
#    'quicksort_ascend': 0.0017050000005838228,
#    'selectsort_ascend': 0.5622472000004564}},
#  'duplicated_6000_1': {'type': 'duplicated',
#   'length': 6000,
#   'seed': 2290,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 1.550609699999768,
#    'heapsort_ascend': 0.022939800000131072,
#    'insertsort_ascend': 0.5169083999999202,
#    'mergesort_ascend': 0.016483899999911955,
#    'quicksort_ascend': 0.0017542999994475394,
#    'selectsort_ascend': 0.6519570000000385}},
#  'duplicated_6000_2': {'type': 'duplicated',
#   'length': 6000,
#   'seed': 7301,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 1.8754447999999684,
#    'heapsort_ascend': 0.0230251999992106,
#    'insertsort_ascend': 0.5121570999999676,
#    'mergesort_ascend': 0.018817500000295695,
#    'quicksort_ascend': 0.0017370999994454905,
#    'selectsort_ascend': 0.6238573999999062}},
#  'duplicated_7000_0': {'type': 'duplicated',
#   'length': 7000,
#   'seed': 9167,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.129372199999125,
#    'heapsort_ascend': 0.030457599999863305,
#    'insertsort_ascend': 0.6962183999994522,
#    'mergesort_ascend': 0.021460900000420224,
#    'quicksort_ascend': 0.0027344000000084634,
#    'selectsort_ascend': 0.7702492000007624}},
#  'duplicated_7000_1': {'type': 'duplicated',
#   'length': 7000,
#   'seed': 6298,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 2.189211000000796,
#    'heapsort_ascend': 0.027660200000354962,
#    'insertsort_ascend': 0.7052343000004839,
#    'mergesort_ascend': 0.020024299999931827,
#    'quicksort_ascend': 0.0017876000001706416,
#    'selectsort_ascend': 0.7259383000000525}},
#  'duplicated_7000_2': {'type': 'duplicated',
#   'length': 7000,
#   'seed': 5724,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 2.066507499999716,
#    'heapsort_ascend': 0.025857900000119116,
#    'insertsort_ascend': 0.729443899999751,
#    'mergesort_ascend': 0.01972680000017135,
#    'quicksort_ascend': 0.0022681999998894753,
#    'selectsort_ascend': 0.7309118000002854}},
#  'duplicated_8000_0': {'type': 'duplicated',
#   'length': 8000,
#   'seed': 9551,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.65763220000008,
#    'heapsort_ascend': 0.030591300000196497,
#    'insertsort_ascend': 0.9057235000000219,
#    'mergesort_ascend': 0.022343300000102317,
#    'quicksort_ascend': 0.002377400000113994,
#    'selectsort_ascend': 1.0104032000008374}},
#  'duplicated_8000_1': {'type': 'duplicated',
#   'length': 8000,
#   'seed': 7961,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 2.6768002999997407,
#    'heapsort_ascend': 0.031311900000218884,
#    'insertsort_ascend': 0.917563699999846,
#    'mergesort_ascend': 0.02304679999997461,
#    'quicksort_ascend': 0.0022366000002875808,
#    'selectsort_ascend': 0.9691640000000916}},
#  'duplicated_8000_2': {'type': 'duplicated',
#   'length': 8000,
#   'seed': 6125,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 2.660403800000495,
#    'heapsort_ascend': 0.032097900000735535,
#    'insertsort_ascend': 0.9361710000002859,
#    'mergesort_ascend': 0.024613900000076683,
#    'quicksort_ascend': 0.002066400000330759,
#    'selectsort_ascend': 1.3205183000000034}},
#  'duplicated_9000_0': {'type': 'duplicated',
#   'length': 9000,
#   'seed': 9935,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 3.6051982999997563,
#    'heapsort_ascend': 0.03563839999969787,
#    'insertsort_ascend': 1.1795984000000317,
#    'mergesort_ascend': 0.028133099999649858,
#    'quicksort_ascend': 0.0027435000001787557,
#    'selectsort_ascend': 1.2998402000002898}},
#  'duplicated_9000_1': {'type': 'duplicated',
#   'length': 9000,
#   'seed': 8204,
#   'sample_id': 1,
#   'result': {'bubblesort_ascend': 3.730843599999389,
#    'heapsort_ascend': 0.04050649999953748,
#    'insertsort_ascend': 1.3611928000000262,
#    'mergesort_ascend': 0.03570630000012898,
#    'quicksort_ascend': 0.0029264000004332047,
#    'selectsort_ascend': 1.4323104000004605}},
#  'duplicated_9000_2': {'type': 'duplicated',
#   'length': 9000,
#   'seed': 215,
#   'sample_id': 2,
#   'result': {'bubblesort_ascend': 3.5235520000005636,
#    'heapsort_ascend': 0.03966870000022027,
#    'insertsort_ascend': 1.1568944999999076,
#    'mergesort_ascend': 0.026545599999735714,
#    'quicksort_ascend': 0.0028991999997742823,
#    'selectsort_ascend': 1.2285768000001553}},
#  'sorted_1_0': {'type': 'sorted',
#   'length': 1,
#   'seed': 455,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 3.0000000000030003e-06,
#    'heapsort_ascend': 6.199999999997874e-06,
#    'insertsort_ascend': 2.000000000002e-06,
#    'mergesort_ascend': 1.6000000000009063e-06,
#    'quicksort_ascend': 1.1999999999998123e-06,
#    'selectsort_ascend': 1.8999999999991246e-06}},
#  'sorted_10_0': {'type': 'sorted',
#   'length': 10,
#   'seed': 6263,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 7.80000000000225e-06,
#    'heapsort_ascend': 3.500000000000031e-05,
#    'insertsort_ascend': 8.999999999998592e-06,
#    'mergesort_ascend': 3.779999999999756e-05,
#    'quicksort_ascend': 8.79999999999978e-06,
#    'selectsort_ascend': 7.400000000001156e-06}},
#  'sorted_100_0': {'type': 'sorted',
#   'length': 100,
#   'seed': 8443,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.00027639999999999956,
#    'heapsort_ascend': 0.00023779999999999982,
#    'insertsort_ascend': 0.00023839999999999972,
#    'mergesort_ascend': 0.00017210000000000142,
#    'quicksort_ascend': 9.610000000000174e-05,
#    'selectsort_ascend': 0.00019539999999999835}},
#  'sorted_1000_0': {'type': 'sorted',
#   'length': 1000,
#   'seed': 2817,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.03068159999997988,
#    'heapsort_ascend': 0.002984799999921961,
#    'insertsort_ascend': 0.027558499999940977,
#    'mergesort_ascend': 0.0045898000000761385,
#    'quicksort_ascend': 0.0015846000000010463,
#    'selectsort_ascend': 0.016064199999959783}},
#  'sorted_10000_0': {'type': 'sorted',
#   'length': 10000,
#   'seed': 5793,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.3950371,
#    'heapsort_ascend': 0.04553679999999982,
#    'insertsort_ascend': 2.5950629000000003,
#    'mergesort_ascend': 0.022641099999999525,
#    'quicksort_ascend': 0.009929599999999539,
#    'selectsort_ascend': 1.4545642}},
#  'sorted_100000_0': {'type': 'sorted',
#   'length': 100000,
#   'seed': 6167,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 332.7729148,
#    'heapsort_ascend': 0.6441368000000125,
#    'insertsort_ascend': 370.7351081,
#    'mergesort_ascend': 0.4282258999999158,
#    'quicksort_ascend': 0.371577200000047,
#    'selectsort_ascend': 211.4069356}},
#  'sorted_2000_0': {'type': 'sorted',
#   'length': 2000,
#   'seed': 4702,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.10422119999998358,
#    'heapsort_ascend': 0.00881379999998444,
#    'insertsort_ascend': 0.11784309999995912,
#    'mergesort_ascend': 0.004746399999930873,
#    'quicksort_ascend': 0.0017242999999780295,
#    'selectsort_ascend': 0.06253730000003088}},
#  'sorted_3000_0': {'type': 'sorted',
#   'length': 3000,
#   'seed': 3198,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.2528518000000304,
#    'heapsort_ascend': 0.029701799999998002,
#    'insertsort_ascend': 0.27177900000003774,
#    'mergesort_ascend': 0.0075758000000405445,
#    'quicksort_ascend': 0.002917099999990569,
#    'selectsort_ascend': 0.15006049999999505}},
#  'sorted_4000_0': {'type': 'sorted',
#   'length': 4000,
#   'seed': 3264,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.4500446000000693,
#    'heapsort_ascend': 0.016284799999993993,
#    'insertsort_ascend': 0.46033199999999397,
#    'mergesort_ascend': 0.009164199999986522,
#    'quicksort_ascend': 0.004638300000010531,
#    'selectsort_ascend': 0.2654233999999178}},
#  'sorted_5000_0': {'type': 'sorted',
#   'length': 5000,
#   'seed': 471,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.7212895999999773,
#    'heapsort_ascend': 0.020072500000082982,
#    'insertsort_ascend': 0.7102194999999938,
#    'mergesort_ascend': 0.01158100000009199,
#    'quicksort_ascend': 0.00632759999996324,
#    'selectsort_ascend': 0.4178702000000385}},
#  'sorted_6000_0': {'type': 'sorted',
#   'length': 6000,
#   'seed': 2893,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.9781408999999712,
#    'heapsort_ascend': 0.024884899999960908,
#    'insertsort_ascend': 1.0589919000000236,
#    'mergesort_ascend': 0.015034700000001067,
#    'quicksort_ascend': 0.007458399999904941,
#    'selectsort_ascend': 0.5858991999999716}},
#  'sorted_7000_0': {'type': 'sorted',
#   'length': 7000,
#   'seed': 6835,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.3415683000000627,
#    'heapsort_ascend': 0.03853900000001431,
#    'insertsort_ascend': 1.4315212999999858,
#    'mergesort_ascend': 0.01883820000000469,
#    'quicksort_ascend': 0.008105099999966114,
#    'selectsort_ascend': 0.8050523000000567}},
#  'sorted_8000_0': {'type': 'sorted',
#   'length': 8000,
#   'seed': 4604,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.959703999999988,
#    'heapsort_ascend': 0.03487350000000333,
#    'insertsort_ascend': 1.8817362999999432,
#    'mergesort_ascend': 0.022721100000012484,
#    'quicksort_ascend': 0.008597100000088176,
#    'selectsort_ascend': 1.0722350999999435}},
#  'sorted_9000_0': {'type': 'sorted',
#   'length': 9000,
#   'seed': 42,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.32277739999995,
#    'heapsort_ascend': 0.039637599999991835,
#    'insertsort_ascend': 2.381845999999996,
#    'mergesort_ascend': 0.035210399999982656,
#    'quicksort_ascend': 0.014768599999911203,
#    'selectsort_ascend': 1.482225900000003}},
#  'reverse_1_0': {'type': 'reverse',
#   'length': 1,
#   'seed': 5679,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 8.71000000870481e-05,
#    'heapsort_ascend': 7.900000014160469e-06,
#    'insertsort_ascend': 1.6000000186977559e-06,
#    'mergesort_ascend': 1.1999999287581886e-06,
#    'quicksort_ascend': 8.000000661922968e-07,
#    'selectsort_ascend': 1.4999999393694452e-06}},
#  'reverse_10_0': {'type': 'reverse',
#   'length': 10,
#   'seed': 743,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 8.500000035382982e-06,
#    'heapsort_ascend': 2.159999996820261e-05,
#    'insertsort_ascend': 3.6999999792897142e-06,
#    'mergesort_ascend': 1.550000001770968e-05,
#    'quicksort_ascend': 9.500000032858225e-06,
#    'selectsort_ascend': 5.400000077315781e-06}},
#  'reverse_100_0': {'type': 'reverse',
#   'length': 100,
#   'seed': 4194,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.0006508999999823573,
#    'heapsort_ascend': 0.0005127000000584303,
#    'insertsort_ascend': 4.179999996267725e-05,
#    'mergesort_ascend': 0.000268899999923633,
#    'quicksort_ascend': 8.350000007339986e-05,
#    'selectsort_ascend': 0.00020099999994727114}},
#  'reverse_1000_0': {'type': 'reverse',
#   'length': 1000,
#   'seed': 7509,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.07964289999995344,
#    'heapsort_ascend': 0.004336599999987811,
#    'insertsort_ascend': 0.00055859999997665,
#    'mergesort_ascend': 0.0021964000000025408,
#    'quicksort_ascend': 0.0016134999998485,
#    'selectsort_ascend': 0.023046299999805342}},
#  'reverse_10000_0': {'type': 'reverse',
#   'length': 10000,
#   'seed': 9209,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 6.8383177000000614,
#    'heapsort_ascend': 0.05172230000005129,
#    'insertsort_ascend': 0.03704329999993661,
#    'mergesort_ascend': 0.024636900000018613,
#    'quicksort_ascend': 0.012889599999994061,
#    'selectsort_ascend': 2.0292547999999897}},
#  'reverse_100000_0': {'type': 'reverse',
#   'length': 100000,
#   'seed': 672,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 791.8978759,
#    'heapsort_ascend': 0.6730651000000307,
#    'insertsort_ascend': 3.649192200000016,
#    'mergesort_ascend': 0.3339936000002126,
#    'quicksort_ascend': 0.15903980000007323,
#    'selectsort_ascend': 250.17796610000005}},
#  'reverse_2000_0': {'type': 'reverse',
#   'length': 2000,
#   'seed': 6387,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.28667889999996987,
#    'heapsort_ascend': 0.008781900000030873,
#    'insertsort_ascend': 0.002237300000160758,
#    'mergesort_ascend': 0.006474300000036237,
#    'quicksort_ascend': 0.002311299999973926,
#    'selectsort_ascend': 0.08543700000018362}},
#  'reverse_3000_0': {'type': 'reverse',
#   'length': 3000,
#   'seed': 4819,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.6686628999998447,
#    'heapsort_ascend': 0.014561299999968469,
#    'insertsort_ascend': 0.004050199999937831,
#    'mergesort_ascend': 0.007554400000117312,
#    'quicksort_ascend': 0.004370699999981298,
#    'selectsort_ascend': 0.18563930000004802}},
#  'reverse_4000_0': {'type': 'reverse',
#   'length': 4000,
#   'seed': 827,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.111939300000131,
#    'heapsort_ascend': 0.02178830000002563,
#    'insertsort_ascend': 0.0063357000001360575,
#    'mergesort_ascend': 0.010559499999999389,
#    'quicksort_ascend': 0.0036220999998022307,
#    'selectsort_ascend': 0.31624620000002324}},
#  'reverse_5000_0': {'type': 'reverse',
#   'length': 5000,
#   'seed': 4612,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.752259800000047,
#    'heapsort_ascend': 0.022858600000063234,
#    'insertsort_ascend': 0.009552900000016962,
#    'mergesort_ascend': 0.011279800000011164,
#    'quicksort_ascend': 0.006306200000153694,
#    'selectsort_ascend': 0.46656720000009955}},
#  'reverse_6000_0': {'type': 'reverse',
#   'length': 6000,
#   'seed': 9055,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.392688299999918,
#    'heapsort_ascend': 0.03453369999988354,
#    'insertsort_ascend': 0.014123899999958667,
#    'mergesort_ascend': 0.013977600000089296,
#    'quicksort_ascend': 0.007111500000064552,
#    'selectsort_ascend': 0.737078800000063}},
#  'reverse_7000_0': {'type': 'reverse',
#   'length': 7000,
#   'seed': 6168,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 3.4540613000001485,
#    'heapsort_ascend': 0.03557219999993322,
#    'insertsort_ascend': 0.022325600000158374,
#    'mergesort_ascend': 0.019608699999935197,
#    'quicksort_ascend': 0.00984840000000986,
#    'selectsort_ascend': 0.9517077000000427}},
#  'reverse_8000_0': {'type': 'reverse',
#   'length': 8000,
#   'seed': 4299,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 4.393341699999837,
#    'heapsort_ascend': 0.039537099999961356,
#    'insertsort_ascend': 0.027654699999857257,
#    'mergesort_ascend': 0.020851600000014514,
#    'quicksort_ascend': 0.008927099999937127,
#    'selectsort_ascend': 1.2823818000001665}},
#  'reverse_9000_0': {'type': 'reverse',
#   'length': 9000,
#   'seed': 9017,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 5.8705116000001,
#    'heapsort_ascend': 0.04500980000011623,
#    'insertsort_ascend': 0.03573240000014266,
#    'mergesort_ascend': 0.025293000000147003,
#    'quicksort_ascend': 0.01280429999997068,
#    'selectsort_ascend': 1.7077523999998903}},
#  'equal_1_0': {'type': 'equal',
#   'length': 1,
#   'seed': 953,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.00016809999988254276,
#    'heapsort_ascend': 2.3899999860077514e-05,
#    'insertsort_ascend': 1.6999999843392288e-06,
#    'mergesort_ascend': 1.9999999949504854e-06,
#    'quicksort_ascend': 1.2000000424450263e-06,
#    'selectsort_ascend': 2.100000074278796e-06}},
#  'equal_10_0': {'type': 'equal',
#   'length': 10,
#   'seed': 66,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 8.499999921696144e-06,
#    'heapsort_ascend': 1.8999999838342774e-05,
#    'insertsort_ascend': 9.69999996414117e-06,
#    'mergesort_ascend': 2.369999992879457e-05,
#    'quicksort_ascend': 4.699999863078119e-06,
#    'selectsort_ascend': 6.799999937356915e-06}},
#  'equal_100_0': {'type': 'equal',
#   'length': 100,
#   'seed': 1160,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.0002647000001161359,
#    'heapsort_ascend': 9.81999999112304e-05,
#    'insertsort_ascend': 0.00035840000009557116,
#    'mergesort_ascend': 0.00022520000015902042,
#    'quicksort_ascend': 1.7299999854003545e-05,
#    'selectsort_ascend': 0.0003230999998322659}},
#  'equal_1000_0': {'type': 'equal',
#   'length': 1000,
#   'seed': 6770,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.027299600000333157,
#    'heapsort_ascend': 0.0007595000001856533,
#    'insertsort_ascend': 0.03627580000011221,
#    'mergesort_ascend': 0.002978799999709736,
#    'quicksort_ascend': 0.00016140000025188783,
#    'selectsort_ascend': 0.015369400000054156}},
#  'equal_10000_0': {'type': 'equal',
#   'length': 10000,
#   'seed': 7484,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.7856137999999646,
#    'heapsort_ascend': 0.0070069999999304855,
#    'insertsort_ascend': 3.0933959999999843,
#    'mergesort_ascend': 0.03124749999983578,
#    'quicksort_ascend': 0.0008366999998088431,
#    'selectsort_ascend': 1.558392700000013}},
#  'equal_100000_0': {'type': 'equal',
#   'length': 100000,
#   'seed': 3819,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 274.9376897999998,
#    'heapsort_ascend': 0.087329000000409,
#    'insertsort_ascend': 301.42038139999977,
#    'mergesort_ascend': 0.3635652999996637,
#    'quicksort_ascend': 0.011589400000048045,
#    'selectsort_ascend': 168.31747859999996}},
#  'equal_2000_0': {'type': 'equal',
#   'length': 2000,
#   'seed': 3758,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.10765219999984765,
#    'heapsort_ascend': 0.0013371999998526007,
#    'insertsort_ascend': 0.11228889999983949,
#    'mergesort_ascend': 0.005308199999944918,
#    'quicksort_ascend': 0.00028969999993933016,
#    'selectsort_ascend': 0.06753789999993387}},
#  'equal_3000_0': {'type': 'equal',
#   'length': 3000,
#   'seed': 8499,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.24661860000014713,
#    'heapsort_ascend': 0.0035320000001775043,
#    'insertsort_ascend': 0.2538886999996066,
#    'mergesort_ascend': 0.009847199999967415,
#    'quicksort_ascend': 0.00033179999991261866,
#    'selectsort_ascend': 0.13552449999997407}},
#  'equal_4000_0': {'type': 'equal',
#   'length': 4000,
#   'seed': 7408,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.47796980000020994,
#    'heapsort_ascend': 0.0037172000002101413,
#    'insertsort_ascend': 0.45566390000021784,
#    'mergesort_ascend': 0.014891000000261556,
#    'quicksort_ascend': 0.0004853999998886138,
#    'selectsort_ascend': 0.2592920000001868}},
#  'equal_5000_0': {'type': 'equal',
#   'length': 5000,
#   'seed': 415,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.6388947000000371,
#    'heapsort_ascend': 0.004223299999921437,
#    'insertsort_ascend': 0.7935500999997203,
#    'mergesort_ascend': 0.017357600000195816,
#    'quicksort_ascend': 0.0005398999996941711,
#    'selectsort_ascend': 0.39302660000021206}},
#  'equal_6000_0': {'type': 'equal',
#   'length': 6000,
#   'seed': 5557,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.9619535000001633,
#    'heapsort_ascend': 0.006013900000198191,
#    'insertsort_ascend': 1.0656514000002062,
#    'mergesort_ascend': 0.021122900000136724,
#    'quicksort_ascend': 0.0004992999997739389,
#    'selectsort_ascend': 0.5994924000001447}},
#  'equal_7000_0': {'type': 'equal',
#   'length': 7000,
#   'seed': 7613,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.2679006000003028,
#    'heapsort_ascend': 0.010426600000300823,
#    'insertsort_ascend': 1.4357709999999315,
#    'mergesort_ascend': 0.021974499999942054,
#    'quicksort_ascend': 0.0007249999998748535,
#    'selectsort_ascend': 0.7168899000002966}},
#  'equal_8000_0': {'type': 'equal',
#   'length': 8000,
#   'seed': 4721,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.6975324,
#    'heapsort_ascend': 0.006949900000108755,
#    'insertsort_ascend': 1.9118438999998943,
#    'mergesort_ascend': 0.0241678000002139,
#    'quicksort_ascend': 0.0007749999999759893,
#    'selectsort_ascend': 0.9993299999996452}},
#  'equal_9000_0': {'type': 'equal',
#   'length': 9000,
#   'seed': 5833,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.2221729000002597,
#    'heapsort_ascend': 0.012479099999836762,
#    'insertsort_ascend': 2.396926800000074,
#    'mergesort_ascend': 0.029458599999998114,
#    'quicksort_ascend': 0.0007575999998152838,
#    'selectsort_ascend': 1.2794965999996748}},
#  'jag_1_0': {'type': 'jag',
#   'length': 1,
#   'seed': 3792,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.4600000213249587e-05,
#    'heapsort_ascend': 6.8999997893115506e-06,
#    'insertsort_ascend': 1.7999996089201886e-06,
#    'mergesort_ascend': 1.5999999050109182e-06,
#    'quicksort_ascend': 1.499999598308932e-06,
#    'selectsort_ascend': 1.8000000636675395e-06}},
#  'jag_10_0': {'type': 'jag',
#   'length': 10,
#   'seed': 7900,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.3299999864102574e-05,
#    'heapsort_ascend': 2.5899999855028e-05,
#    'insertsort_ascend': 9.899999895424116e-06,
#    'mergesort_ascend': 2.4700000267330324e-05,
#    'quicksort_ascend': 1.3800000033370452e-05,
#    'selectsort_ascend': 9.800000043469481e-06}},
#  'jag_100_0': {'type': 'jag',
#   'length': 100,
#   'seed': 3631,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.0004795999998350453,
#    'heapsort_ascend': 0.0002752999998847372,
#    'insertsort_ascend': 0.00017179999986183248,
#    'mergesort_ascend': 0.00019250000013926183,
#    'quicksort_ascend': 0.00023989999999685097,
#    'selectsort_ascend': 0.00015419999999721767}},
#  'jag_1000_0': {'type': 'jag',
#   'length': 1000,
#   'seed': 615,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.04690520000031029,
#    'heapsort_ascend': 0.0043441999996503,
#    'insertsort_ascend': 0.01444790000005014,
#    'mergesort_ascend': 0.0022002999999131134,
#    'quicksort_ascend': 0.001092900000003283,
#    'selectsort_ascend': 0.01640869999982897}},
#  'jag_10000_0': {'type': 'jag',
#   'length': 10000,
#   'seed': 3341,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 4.925404600000093,
#    'heapsort_ascend': 0.05167289999963032,
#    'insertsort_ascend': 1.53999500000009,
#    'mergesort_ascend': 0.03590619999977207,
#    'quicksort_ascend': 0.01444549999996525,
#    'selectsort_ascend': 1.7537013999999544}},
#  'jag_100000_0': {'type': 'jag',
#   'length': 100000,
#   'seed': 3321,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 514.2347390999998,
#    'heapsort_ascend': 0.6156052999999702,
#    'insertsort_ascend': 161.80374500000016,
#    'mergesort_ascend': 0.347309100000075,
#    'quicksort_ascend': 0.1505541000001358,
#    'selectsort_ascend': 200.95601669999996}},
#  'jag_2000_0': {'type': 'jag',
#   'length': 2000,
#   'seed': 3785,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.18433450000020457,
#    'heapsort_ascend': 0.009884000000056403,
#    'insertsort_ascend': 0.058502899999894,
#    'mergesort_ascend': 0.006228499999906489,
#    'quicksort_ascend': 0.0025255999998989864,
#    'selectsort_ascend': 0.06441080000013244}},
#  'jag_3000_0': {'type': 'jag',
#   'length': 3000,
#   'seed': 2204,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.4351093000000219,
#    'heapsort_ascend': 0.015433800000209885,
#    'insertsort_ascend': 0.12909559999980047,
#    'mergesort_ascend': 0.01061200000003737,
#    'quicksort_ascend': 0.005767300000115938,
#    'selectsort_ascend': 0.17769779999980528}},
#  'jag_4000_0': {'type': 'jag',
#   'length': 4000,
#   'seed': 890,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 0.7524773999998615,
#    'heapsort_ascend': 0.018567199999779405,
#    'insertsort_ascend': 0.23557620000019597,
#    'mergesort_ascend': 0.014032200000201556,
#    'quicksort_ascend': 0.0042388000001665205,
#    'selectsort_ascend': 0.2641791999999441}},
#  'jag_5000_0': {'type': 'jag',
#   'length': 5000,
#   'seed': 792,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.1713535999997475,
#    'heapsort_ascend': 0.024123099999997066,
#    'insertsort_ascend': 0.4153843999997662,
#    'mergesort_ascend': 0.016200900000058027,
#    'quicksort_ascend': 0.00742900000022928,
#    'selectsort_ascend': 0.4587648000001536}},
#  'jag_6000_0': {'type': 'jag',
#   'length': 6000,
#   'seed': 9363,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 1.8575551999997515,
#    'heapsort_ascend': 0.04979479999974501,
#    'insertsort_ascend': 0.5899742000001424,
#    'mergesort_ascend': 0.018839999999727297,
#    'quicksort_ascend': 0.006653700000242679,
#    'selectsort_ascend': 0.6430908000002091}},
#  'jag_7000_0': {'type': 'jag',
#   'length': 7000,
#   'seed': 6749,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 2.377439900000354,
#    'heapsort_ascend': 0.031132000000070548,
#    'insertsort_ascend': 0.6909740000000966,
#    'mergesort_ascend': 0.020785199999863835,
#    'quicksort_ascend': 0.009292499999901338,
#    'selectsort_ascend': 0.845558500000152}},
#  'jag_8000_0': {'type': 'jag',
#   'length': 8000,
#   'seed': 2224,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 3.010732000000189,
#    'heapsort_ascend': 0.039510300000074494,
#    'insertsort_ascend': 0.9583376000000499,
#    'mergesort_ascend': 0.03204779999987295,
#    'quicksort_ascend': 0.012200699999993958,
#    'selectsort_ascend': 1.1066960000002837}},
#  'jag_9000_0': {'type': 'jag',
#   'length': 9000,
#   'seed': 2919,
#   'sample_id': 0,
#   'result': {'bubblesort_ascend': 4.132609400000092,
#    'heapsort_ascend': 0.049823100000139675,
#    'insertsort_ascend': 1.2785335000003215,
#    'mergesort_ascend': 0.027388499999688065,
#    'quicksort_ascend': 0.013997399999880145,
#    'selectsort_ascend': 1.3665287999997418}}}

# %%
results_by_length
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {1: defaultdict(list,
#                          {'bubblesort_ascend': [2.3000000000002185e-06,
#                            1.7999999999997185e-06,
#                            2.4999999999990308e-06],
#                           'heapsort_ascend': [6.699999999998374e-06,
#                            1.5199999999999936e-05,
#                            4.199999999999343e-06],
#                           'insertsort_ascend': [1.7999999999997185e-06,
#                            1.7999999999997185e-06,
#                            1.2999999999992184e-06],
#                           'mergesort_ascend': [9.999999999975306e-07,
#                            1.7000000000003124e-06,
#                            8.999999999981245e-07],
#                           'quicksort_ascend': [1.7999999999997185e-06,
#                            1.1999999999998123e-06,
#                            1.000000000001e-06],
#                           'selectsort_ascend': [3.199999999998343e-06,
#                            2.8000000000007186e-06,
#                            1.4999999999980307e-06]}),
#              10: defaultdict(list,
#                          {'bubblesort_ascend': [1.2400000000002687e-05,
#                            1.0799999999998311e-05,
#                            1.2200000000000405e-05],
#                           'heapsort_ascend': [3.3600000000001684e-05,
#                            3.18999999999979e-05,
#                            3.3299999999999996e-05],
#                           'insertsort_ascend': [1.6000000000002124e-05,
#                            1.0099999999998999e-05,
#                            8.500000000001562e-06],
#                           'mergesort_ascend': [2.839999999999787e-05,
#                            2.9799999999999965e-05,
#                            2.8000000000000247e-05],
#                           'quicksort_ascend': [1.5500000000001624e-05,
#                            1.860000000000056e-05,
#                            1.0500000000000093e-05],
#                           'selectsort_ascend': [1.0799999999998311e-05,
#                            8.999999999998592e-06,
#                            8.199999999999874e-06]}),
#              100: defaultdict(list,
#                          {'bubblesort_ascend': [0.0012469999999999981,
#                            0.000764299999999999,
#                            0.00043430000000000205],
#                           'heapsort_ascend': [0.0008691000000000011,
#                            0.0007766999999999982,
#                            0.00028000000000000247],
#                           'insertsort_ascend': [0.00025099999999999775,
#                            0.00018270000000000092,
#                            0.00015099999999999836],
#                           'mergesort_ascend': [0.0004275000000000008,
#                            0.0002707999999999981,
#                            0.0002711999999999992],
#                           'quicksort_ascend': [0.00019759999999999917,
#                            0.00017239999999999964,
#                            0.0001436999999999966],
#                           'selectsort_ascend': [0.0005056000000000019,
#                            0.0003516000000000005,
#                            0.00022869999999999835]}),
#              1000: defaultdict(list,
#                          {'bubblesort_ascend': [0.06616959999973915,
#                            0.05984520000038174,
#                            0.07554540000000998],
#                           'heapsort_ascend': [0.006255000000237487,
#                            0.004137599999921804,
#                            0.00643209999998362],
#                           'insertsort_ascend': [0.0160185999998248,
#                            0.021934800000053656,
#                            0.015605600000071718],
#                           'mergesort_ascend': [0.0032983999999487423,
#                            0.0054556999998567335,
#                            0.0026385999999547494],
#                           'quicksort_ascend': [0.0016909999999370484,
#                            0.0024966000000858912,
#                            0.0013018999998166692],
#                           'selectsort_ascend': [0.01940710000008039,
#                            0.023052799999732088,
#                            0.017826700000114215]}),
#              10000: defaultdict(list,
#                          {'bubblesort_ascend': [4.6621852,
#                            5.096818900000001,
#                            5.3186246],
#                           'heapsort_ascend': [0.06013599999999997,
#                            0.04776430000000076,
#                            0.06650259999999975],
#                           'insertsort_ascend': [1.4164987,
#                            1.4651422000000007,
#                            1.9820768999999991],
#                           'mergesort_ascend': [0.041037400000000446,
#                            0.031245800000000656,
#                            0.03486249999999913],
#                           'quicksort_ascend': [0.019072200000000095,
#                            0.01921610000000129,
#                            0.01668430000000143],
#                           'selectsort_ascend': [1.6159227999999999,
#                            1.6811211000000004,
#                            1.6984808999999998]}),
#              100000: defaultdict(list,
#                          {'bubblesort_ascend': [558.4179514,
#                            607.4739491,
#                            521.9693106999998],
#                           'heapsort_ascend': [0.7415236000000505,
#                            0.7391153000000941,
#                            0.6224857000001975],
#                           'insertsort_ascend': [191.14149180000004,
#                            181.80719900000008,
#                            155.86315239999976],
#                           'mergesort_ascend': [0.5709229999999934,
#                            0.4130299000000832,
#                            0.38266590000012],
#                           'quicksort_ascend': [0.2715327000000798,
#                            0.21644599999990533,
#                            0.20175749999998516],
#                           'selectsort_ascend': [176.51122959999998,
#                            166.8976760999999,
#                            169.34699799999999]}),
#              2000: defaultdict(list,
#                          {'bubblesort_ascend': [0.20933970000032787,
#                            0.20088609999993423,
#                            0.20797540000012305],
#                           'heapsort_ascend': [0.007721599999968021,
#                            0.00793489999978192,
#                            0.007889199999681296],
#                           'insertsort_ascend': [0.06225589999985459,
#                            0.06384329999991678,
#                            0.05740659999992204],
#                           'mergesort_ascend': [0.0050138999999944645,
#                            0.005283700000290992,
#                            0.005046699999638804],
#                           'quicksort_ascend': [0.0025793999998313666,
#                            0.002587299999959214,
#                            0.0024764999998296844],
#                           'selectsort_ascend': [0.0642811999996411,
#                            0.130130100000315,
#                            0.06517600000006496]}),
#              3000: defaultdict(list,
#                          {'bubblesort_ascend': [0.43233569999983956,
#                            0.41443400000025576,
#                            0.43539389999978084],
#                           'heapsort_ascend': [0.011689599999954225,
#                            0.012079199999789125,
#                            0.011824500000329863],
#                           'insertsort_ascend': [0.12078269999983604,
#                            0.13022069999988162,
#                            0.14932939999971495],
#                           'mergesort_ascend': [0.0076902000000700355,
#                            0.007900699999936478,
#                            0.008599199999935081],
#                           'quicksort_ascend': [0.0037850000003345485,
#                            0.003946399999676942,
#                            0.004207200000109879],
#                           'selectsort_ascend': [0.13831889999983105,
#                            0.1452606999996533,
#                            0.1493428999997377]}),
#              4000: defaultdict(list,
#                          {'bubblesort_ascend': [0.7934540999999626,
#                            0.9220070999999734,
#                            1.1395458999995753],
#                           'heapsort_ascend': [0.01719279999997525,
#                            0.023649099999602186,
#                            0.01921360000005734],
#                           'insertsort_ascend': [0.24930589999985386,
#                            0.29641750000018874,
#                            0.2593968999999561],
#                           'mergesort_ascend': [0.022382199999810837,
#                            0.022335199999815813,
#                            0.01169770000024073],
#                           'quicksort_ascend': [0.01632259999996677,
#                            0.007869300000038493,
#                            0.00631729999986419],
#                           'selectsort_ascend': [0.34113029999980427,
#                            0.32088849999991,
#                            0.25819559999990815]}),
#              5000: defaultdict(list,
#                          {'bubblesort_ascend': [1.2118093999997654,
#                            1.4168690999999853,
#                            1.20237810000026],
#                           'heapsort_ascend': [0.02158030000009603,
#                            0.02136030000019673,
#                            0.02267470000015237],
#                           'insertsort_ascend': [0.36044070000025386,
#                            0.3408118000002105,
#                            0.37946270000020377],
#                           'mergesort_ascend': [0.013015400000313093,
#                            0.013167800000246643,
#                            0.013639100000091275],
#                           'quicksort_ascend': [0.006787499999973079,
#                            0.006513700000141398,
#                            0.006717700000081095],
#                           'selectsort_ascend': [0.4233509000000595,
#                            0.3790162999998756,
#                            0.43335639999986597]}),
#              6000: defaultdict(list,
#                          {'bubblesort_ascend': [1.6994629000000714,
#                            1.7199459999997089,
#                            2.0369136999997863],
#                           'heapsort_ascend': [0.02574720000029629,
#                            0.023787699999957113,
#                            0.031014700000014273],
#                           'insertsort_ascend': [0.5584745999999541,
#                            0.469139400000131,
#                            0.6157831999998962],
#                           'mergesort_ascend': [0.018413699999655364,
#                            0.015296699999908014,
#                            0.01769190000004528],
#                           'quicksort_ascend': [0.009135700000115321,
#                            0.007796500000040396,
#                            0.008568799999920884],
#                           'selectsort_ascend': [0.5840502999999444,
#                            0.5308604000001651,
#                            0.595774899999924]}),
#              7000: defaultdict(list,
#                          {'bubblesort_ascend': [2.397841999999855,
#                            2.5045666000000892,
#                            2.614981899999748],
#                           'heapsort_ascend': [0.03378229999998439,
#                            0.03184980000014548,
#                            0.04625639999994746],
#                           'insertsort_ascend': [0.7363165000001572,
#                            0.7975987999998324,
#                            0.8765034000002743],
#                           'mergesort_ascend': [0.019702999999935855,
#                            0.020189299999856303,
#                            0.02068280000003142],
#                           'quicksort_ascend': [0.010675200000150653,
#                            0.01160070000014457,
#                            0.01021149999996851],
#                           'selectsort_ascend': [0.7923639999999068,
#                            0.8930817999998908,
#                            0.8500900999997612]}),
#              8000: defaultdict(list,
#                          {'bubblesort_ascend': [3.282195100000081,
#                            3.4499728000000687,
#                            3.193297899999834],
#                           'heapsort_ascend': [0.0372256999999081,
#                            0.06091459999970539,
#                            0.040410699999938515],
#                           'insertsort_ascend': [0.9764655000003586,
#                            1.2460900000000947,
#                            1.0765566000000035],
#                           'mergesort_ascend': [0.024290100000143866,
#                            0.027866899999935413,
#                            0.02303040000015244],
#                           'quicksort_ascend': [0.012814799999887327,
#                            0.020919099999900936,
#                            0.01290610000023662],
#                           'selectsort_ascend': [1.1032408999999461,
#                            1.1568621999999777,
#                            1.1254587000003085]}),
#              9000: defaultdict(list,
#                          {'bubblesort_ascend': [4.309163299999909,
#                            4.223241500000313,
#                            3.884932999999819],
#                           'heapsort_ascend': [0.04201180000018212,
#                            0.04597719999992478,
#                            0.041280400000232476],
#                           'insertsort_ascend': [1.1739407999998548,
#                            1.1338018999999804,
#                            1.1525805999999648],
#                           'mergesort_ascend': [0.02672519999987344,
#                            0.024050500000157626,
#                            0.024967299999843817],
#                           'quicksort_ascend': [0.013564900000346825,
#                            0.012564600000132486,
#                            0.012871200000063254],
#                           'selectsort_ascend': [1.2796469999998408,
#                            1.1983758999999736,
#                            1.5165797000004204]})})

# %%
# グループ化用の辞書: {length: {algorithm: [time, ...]}}
results_by_length = defaultdict(lambda: defaultdict(list))

# "random" タイプのキーのみ処理する例
for key, entry in data.items():
    # キー例: "random_1000_0" のようになっているので、
    # entry["type"] が "random" のものを対象とする
    if entry.get("type") != "random":
        continue

    length = entry.get("length")
    # 各アルゴリズムごとの実行時間を格納
    for alg, time in entry["result"].items():
        results_by_length[length][alg].append(time)

# 各長さについて平均値を計算
lengths = sorted(results_by_length.keys(), key=lambda x: int(x))
algorithms = ["bubblesort_ascend", "heapsort_ascend", "insertsort_ascend",
              "mergesort_ascend", "quicksort_ascend", "selectsort_ascend"]

avg_results = {alg: [] for alg in algorithms}

for length in lengths:
    for alg in algorithms:
        times = results_by_length[length][alg]
        avg_time = np.mean(times) if times else None
        avg_results[alg].append(avg_time)

# グラフ描画
plt.figure(figsize=(10, 6))
for alg in algorithms:
    plt.plot(lengths, avg_results[alg], marker='o', label=alg)

plt.xlabel("Length")
plt.ylabel("Elapsed Time (s)")
plt.title("Random")
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# グループ化用の辞書: {length: {algorithm: [time, ...]}}
results_by_length = defaultdict(lambda: defaultdict(list))

# "random" タイプのキーのみ処理する例
for key, entry in data.items():
    # キー例: "random_1000_0" のようになっているので、
    # entry["type"] が "random" のものを対象とする
    if entry.get("type") != "duplicated":
        continue

    length = entry.get("length")
    # 各アルゴリズムごとの実行時間を格納
    for alg, time in entry["result"].items():
        results_by_length[length][alg].append(time)

# 各長さについて平均値を計算
lengths = sorted(results_by_length.keys(), key=lambda x: int(x))
algorithms = ["bubblesort_ascend", "heapsort_ascend", "insertsort_ascend",
              "mergesort_ascend", "quicksort_ascend", "selectsort_ascend"]

avg_results = {alg: [] for alg in algorithms}

for length in lengths:
    for alg in algorithms:
        times = results_by_length[length][alg]
        avg_time = np.mean(times) if times else None
        avg_results[alg].append(avg_time)

# グラフ描画
plt.figure(figsize=(10, 6))
for alg in algorithms:
    plt.plot(lengths, avg_results[alg], marker='o', label=alg)

plt.xlabel("Length")
plt.ylabel("Elapsed Time (s)")
plt.title("Duplicated")
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# グループ化用の辞書: {length: {algorithm: [time, ...]}}
results_by_length = defaultdict(lambda: defaultdict(list))

# "random" タイプのキーのみ処理する例
for key, entry in data.items():
    # キー例: "random_1000_0" のようになっているので、
    # entry["type"] が "random" のものを対象とする
    if entry.get("type") != "sorted":
        continue

    length = entry.get("length")
    # 各アルゴリズムごとの実行時間を格納
    for alg, time in entry["result"].items():
        results_by_length[length][alg].append(time)

# 各長さについて平均値を計算
lengths = sorted(results_by_length.keys(), key=lambda x: int(x))
algorithms = ["bubblesort_ascend", "heapsort_ascend", "insertsort_ascend",
              "mergesort_ascend", "quicksort_ascend", "selectsort_ascend"]

avg_results = {alg: [] for alg in algorithms}

for length in lengths:
    for alg in algorithms:
        times = results_by_length[length][alg]
        avg_time = np.mean(times) if times else None
        avg_results[alg].append(avg_time)

# グラフ描画
plt.figure(figsize=(10, 6))
for alg in algorithms:
    plt.plot(lengths, avg_results[alg], marker='o', label=alg)

plt.xlabel("Length")
plt.ylabel("Elapsed Time (s)")
plt.title("Sorted")
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# グループ化用の辞書: {length: {algorithm: [time, ...]}}
results_by_length = defaultdict(lambda: defaultdict(list))

# "random" タイプのキーのみ処理する例
for key, entry in data.items():
    # キー例: "random_1000_0" のようになっているので、
    # entry["type"] が "random" のものを対象とする
    if entry.get("type") != "reverse":
        continue

    length = entry.get("length")
    # 各アルゴリズムごとの実行時間を格納
    for alg, time in entry["result"].items():
        results_by_length[length][alg].append(time)

# 各長さについて平均値を計算
lengths = sorted(results_by_length.keys(), key=lambda x: int(x))
algorithms = ["bubblesort_ascend", "heapsort_ascend", "insertsort_ascend",
              "mergesort_ascend", "quicksort_ascend", "selectsort_ascend"]

avg_results = {alg: [] for alg in algorithms}

for length in lengths:
    for alg in algorithms:
        times = results_by_length[length][alg]
        avg_time = np.mean(times) if times else None
        avg_results[alg].append(avg_time)

# グラフ描画
plt.figure(figsize=(10, 6))
for alg in algorithms:
    plt.plot(lengths, avg_results[alg], marker='o', label=alg)

plt.xlabel("Length")
plt.ylabel("Elapsed Time (s)")
plt.title("Reversed")
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# グループ化用の辞書: {length: {algorithm: [time, ...]}}
results_by_length = defaultdict(lambda: defaultdict(list))

# "random" タイプのキーのみ処理する例
for key, entry in data.items():
    # キー例: "random_1000_0" のようになっているので、
    # entry["type"] が "random" のものを対象とする
    if entry.get("type") != "equal":
        continue

    length = entry.get("length")
    # 各アルゴリズムごとの実行時間を格納
    for alg, time in entry["result"].items():
        results_by_length[length][alg].append(time)

# 各長さについて平均値を計算
lengths = sorted(results_by_length.keys(), key=lambda x: int(x))
algorithms = ["bubblesort_ascend", "heapsort_ascend", "insertsort_ascend",
              "mergesort_ascend", "quicksort_ascend", "selectsort_ascend"]

avg_results = {alg: [] for alg in algorithms}

for length in lengths:
    for alg in algorithms:
        times = results_by_length[length][alg]
        avg_time = np.mean(times) if times else None
        avg_results[alg].append(avg_time)

# グラフ描画
plt.figure(figsize=(10, 6))
for alg in algorithms:
    plt.plot(lengths, avg_results[alg], marker='o', label=alg)

plt.xlabel("Length")
plt.ylabel("Elapsed Time (s)")
plt.title("Equal")
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# グループ化用の辞書: {length: {algorithm: [time, ...]}}
results_by_length = defaultdict(lambda: defaultdict(list))

# "random" タイプのキーのみ処理する例
for key, entry in data.items():
    # キー例: "random_1000_0" のようになっているので、
    # entry["type"] が "random" のものを対象とする
    if entry.get("type") != "equal":
        continue

    length = entry.get("length")
    # 各アルゴリズムごとの実行時間を格納
    for alg, time in entry["result"].items():
        results_by_length[length][alg].append(time)

# 各長さについて平均値を計算
lengths = sorted(results_by_length.keys(), key=lambda x: int(x))
algorithms = ["bubblesort_ascend", "heapsort_ascend", "insertsort_ascend",
              "mergesort_ascend", "quicksort_ascend", "selectsort_ascend"]

avg_results = {alg: [] for alg in algorithms}

for length in lengths:
    for alg in algorithms:
        times = results_by_length[length][alg]
        avg_time = np.mean(times) if times else None
        avg_results[alg].append(avg_time)

# グラフ描画
plt.figure(figsize=(10, 6))
for alg in algorithms:
    plt.plot(lengths, avg_results[alg], marker='o', label=alg)

plt.xlabel("Length")
plt.ylabel("Elapsed Time (s)")
plt.title("Equal")
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.show()
